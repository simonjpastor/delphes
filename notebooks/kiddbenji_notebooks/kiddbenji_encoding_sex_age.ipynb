# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_pickle('../../delphes/data/final4_clean.csv')

# %%
df
# Out:
#      mep_id                        name   country  \
# 0    197490         Magdalena ADAMOWICZ    Poland
# 1    189525                 Asim ADEMOV  Bulgaria
# 2    124831           Isabella ADINOLFI     Italy
# 6    125045              Clara AGUILERA     Spain
# 7    204335            Alviina ALAMETSÄ   Finland
# ..      ...                         ...       ...
# 699  124884             Kosma ZŁOTOWSKI    Poland
# 700  197621  Juan Ignacio ZOIDO ÁLVAREZ     Spain
# 701  124739             Carlos ZORRINHO  Portugal
# 702  185341               Željana ZOVKO   Croatia
# 704   96933                  Milan ZVER  Slovenia
#
#                                                  group  \
# 0    Group of the European People's Party (Christia...
# 1    Group of the European People's Party (Christia...
# 2                                 Non-attached Members
# 6    Group of the Progressive Alliance of Socialist...
# 7           Group of the Greens/European Free Alliance
# ..                                                 ...
# 699        European Conservatives and Reformists Group
# 700  Group of the European People's Party (Christia...
# 701  Group of the Progressive Alliance of Socialist...
# 702  Group of the European People's Party (Christia...
# 704  Group of the European People's Party (Christia...
#
#                                          nat_group          twitter  \
# 0                                      Independent  Adamowicz_Magda
# 1    Citizens for European Development of Bulgaria       AdemovAsim
# 2                               Movimento 5 Stelle     Isa_Adinolfi
# 6                Partido Socialista Obrero Español   ClaraAguilera7
# 7                                    Vihreä liitto  alviinaalametsa
# ..                                             ...              ...
# 699                         Prawo i Sprawiedliwość   KosmaZlotowski
# 700                                Partido Popular          zoidoji
# 701                             Partido Socialista        czorrinho
# 702                 Hrvatska demokratska zajednica          ZovkoEU
# 704                  Slovenska demokratska stranka        MilanZver
#
#                                                content
# 0    [@danutahuebner Bardzo dziękuję @danutahuebner...
# 1    [135 години единна и силна България. \nЧестит ...
# 2    [Sembra un film, ma purtroppo è realtà: le imm...
# 6    [Clara Aguilera: "El criterio científico debe ...
# 7    [@LHurttila @MariaOhisalo Kaupungilla on järje...
# ..                                                 ...
# 699  [https://t.co/7NnVzDXmis, Dziś inauguracja!\nh...
# 700  [Desde @ppegrupo reclamamos una mayor segurida...
# 701  [@sofiaferreira57 O meu mail profissional é pú...
# 702  [Svim učenicima, a naročito prvašićima te njih...
# 704  [Genialno! https://t.co/7L2cpVkVJn, “@Europarl...
#
# [475 rows x 7 columns]

# %%
df = df.reset_index(drop=True)
df = df.drop(columns='index')

# %%
df
# Out:
#      mep_id                        name   country  \
# 0    197490         Magdalena ADAMOWICZ    Poland
# 1    189525                 Asim ADEMOV  Bulgaria
# 2    124831           Isabella ADINOLFI     Italy
# 3    125045              Clara AGUILERA     Spain
# 4    204335            Alviina ALAMETSÄ   Finland
# ..      ...                         ...       ...
# 470  124884             Kosma ZŁOTOWSKI    Poland
# 471  197621  Juan Ignacio ZOIDO ÁLVAREZ     Spain
# 472  124739             Carlos ZORRINHO  Portugal
# 473  185341               Željana ZOVKO   Croatia
# 474   96933                  Milan ZVER  Slovenia
#
#                                                  group  \
# 0    Group of the European People's Party (Christia...
# 1    Group of the European People's Party (Christia...
# 2                                 Non-attached Members
# 3    Group of the Progressive Alliance of Socialist...
# 4           Group of the Greens/European Free Alliance
# ..                                                 ...
# 470        European Conservatives and Reformists Group
# 471  Group of the European People's Party (Christia...
# 472  Group of the Progressive Alliance of Socialist...
# 473  Group of the European People's Party (Christia...
# 474  Group of the European People's Party (Christia...
#
#                                          nat_group          twitter  \
# 0                                      Independent  Adamowicz_Magda
# 1    Citizens for European Development of Bulgaria       AdemovAsim
# 2                               Movimento 5 Stelle     Isa_Adinolfi
# 3                Partido Socialista Obrero Español   ClaraAguilera7
# 4                                    Vihreä liitto  alviinaalametsa
# ..                                             ...              ...
# 470                         Prawo i Sprawiedliwość   KosmaZlotowski
# 471                                Partido Popular          zoidoji
# 472                             Partido Socialista        czorrinho
# 473                 Hrvatska demokratska zajednica          ZovkoEU
# 474                  Slovenska demokratska stranka        MilanZver
#
#                                                content
# 0    [@danutahuebner Bardzo dziękuję @danutahuebner...
# 1    [135 години единна и силна България. \nЧестит ...
# 2    [Sembra un film, ma purtroppo è realtà: le imm...
# 3    [Clara Aguilera: "El criterio científico debe ...
# 4    [@LHurttila @MariaOhisalo Kaupungilla on järje...
# ..                                                 ...
# 470  [https://t.co/7NnVzDXmis, Dziś inauguracja!\nh...
# 471  [Desde @ppegrupo reclamamos una mayor segurida...
# 472  [@sofiaferreira57 O meu mail profissional é pú...
# 473  [Svim učenicima, a naročito prvašićima te njih...
# 474  [Genialno! https://t.co/7L2cpVkVJn, “@Europarl...
#
# [475 rows x 7 columns]

# %%
for key, value in enumerate(df.name):
    print((key, value))
# Out:
# (0, 'Magdalena ADAMOWICZ')
# (1, 'Asim ADEMOV')
# (2, 'Isabella ADINOLFI')
# (3, 'Clara AGUILERA')
# (4, 'Alviina ALAMETSÄ')
# (5, 'Abir AL-SAHLANI')
# (6, 'Andris AMERIKS')
# (7, 'Christine ANDERSON')
# (8, 'Rasmus ANDRESEN')
# (9, 'Eric ANDRIEU')
# (10, 'Nikos ANDROULAKIS')
# (11, 'Marc ANGEL')
# (12, 'Andrus ANSIP')
# (13, 'Maria ARENA')
# (14, 'Pascal ARIMONT')
# (15, 'Bartosz ARŁUKOWICZ')
# (16, 'Clotilde ARMAND')
# (17, 'Anna-Michelle ASIMAKOPOULOU')
# (18, 'Manon AUBRY')
# (19, 'Margrete AUKEN')
# (20, 'Petras AUŠTREVIČIUS')
# (21, 'Malik AZMANI')
# (22, 'Marek Paweł BALT')
# (23, 'Jordan BARDELLA')
# (24, 'Katarina BARLEY')
# (25, 'Pernando BARRENA ARZA')
# (26, 'Traian BĂSESCU')
# (27, 'José Ramón BAUZÁ DÍAZ')
# (28, 'Nicolas BAY')
# (29, 'Nicola BEER')
# (30, 'Tiziana BEGHIN')
# (31, 'Aurelia BEIGNEUX')
# (32, 'François-Xavier BELLAMY')
# (33, 'Brando BENIFEI')
# (34, 'Isabel BENJUMEA BENJUMEA')
# (35, 'Hildegard BENTELE')
# (36, 'Tom BERENDSEN')
# (37, 'Lars Patrick BERG')
# (38, 'Stefan BERGER')
# (39, 'Sergio BERLATO')
# (40, 'Silvio BERLUSCONI')
# (41, 'Robert BIEDROŃ')
# (42, 'Adam BIELAN')
# (43, 'Izaskun BILBAO BARANDICA')
# (44, 'Vladimír BILČÍK')
# (45, 'Dominique BILDE')
# (46, 'Benoît BITEAU')
# (47, 'Malin BJÖRK')
# (48, 'Michael BLOSS')
# (49, 'Andrea BOCSKOR')
# (50, 'Damian BOESELAGER')
# (51, 'Franc BOGOVIČ')
# (52, 'Manuel BOMPARD')
# (53, 'Simona BONAFÈ')
# (54, 'Paolo BORCHIA')
# (55, 'Biljana BORZAN')
# (56, 'Marc BOTENGA')
# (57, 'Gilles BOYER')
# (58, 'Patrick BREYER')
# (59, 'Saskia BRICMONT')
# (60, 'Joachim Stanisław BRUDZIŃSKI')
# (61, 'Annika BRUNA')
# (62, 'Sylvie BRUNET')
# (63, 'Daniel BUDA')
# (64, 'Delara BURKHARDT')
# (65, 'Martin BUSCHMANN')
# (66, 'Jorge BUXADÉ VILLALBA')
# (67, 'Jerzy BUZEK')
# (68, 'Marco CAMPOMENOSI')
# (69, 'Jordi CAÑAS')
# (70, 'Pascal CANFIN')
# (71, 'Damien CARÊME')
# (72, 'Andrea CAROPPO')
# (73, 'Isabel CARVALHAIS')
# (74, 'Maria da Graça CARVALHO')
# (75, 'David CASA')
# (76, 'Daniel CASPARY')
# (77, 'Fabio Massimo CASTALDO')
# (78, 'Pilar del CASTILLO VERA')
# (79, 'Anna CAVAZZINI')
# (80, 'Sara CERDAS')
# (81, 'Catherine CHABAUD')
# (82, 'Mohammed CHAHIM')
# (83, 'Leila CHAIBI')
# (84, 'Caterina CHINNICI')
# (85, 'Lefteris CHRISTOFOROU')
# (86, 'Ilana CICUREL')
# (87, 'Deirdre CLUNE')
# (88, 'Nathalie COLIN-OESTERLÉ')
# (89, 'Gilbert COLLARD')
# (90, 'Antoni COMÍN I OLIVERES')
# (91, 'David CORMAND')
# (92, 'Ignazio CORRAO')
# (93, 'Andrea COZZOLINO')
# (94, 'Katalin CSEH')
# (95, 'Ciarán CUFFE')
# (96, 'Josianne CUTAJAR')
# (97, 'Ryszard CZARNECKI')
# (98, 'Peter van DALEN')
# (99, 'Miriam DALLI')
# (100, 'Jakop G. DALUNDE')
# (101, "Rosa D'AMATO")
# (102, 'Arnaud DANJEAN')
# (103, 'Nicola DANTI')
# (104, 'Salvatore DE MEO')
# (105, 'Paolo DE CASTRO')
# (106, 'Gwendoline DELBOS-CORFIELD')
# (107, 'Andor DELI')
# (108, 'Karima DELLI')
# (109, 'Özlem DEMIREL')
# (110, 'Petra DE SUTTER')
# (111, 'Tamás DEUTSCH')
# (112, 'Geoffroy DIDIER')
# (113, 'Martina DLABAJOVÁ')
# (114, 'Christian DOLESCHAL')
# (115, 'Anna Júlia DONÁTH')
# (116, 'Francesca DONATO')
# (117, 'Herbert DORFMANN')
# (118, 'Marco DREOSTO')
# (119, 'Jarosław DUDA')
# (120, 'Estrella DURÁ FERRANDIS')
# (121, 'Lucia ĎURIŠ NICHOLSONOVÁ')
# (122, 'Angel DZHAMBAZKI')
# (123, 'Bas EICKHOUT')
# (124, 'Derk Jan EPPINK')
# (125, 'Cornelia ERNST')
# (126, 'Ismail ERTUG')
# (127, 'Eleonora EVI')
# (128, 'Agnès EVREN')
# (129, 'Tanja FAJON')
# (130, 'Laurence FARRENG')
# (131, 'Fredrick FEDERLEY')
# (132, 'Markus FERBER')
# (133, 'José Manuel FERNANDES')
# (134, 'Jonás FERNÁNDEZ')
# (135, 'Giuseppe FERRANDINO')
# (136, 'Laura FERRARA')
# (137, 'João FERREIRA')
# (138, 'Carlo FIDANZA')
# (139, 'Pietro FIOCCHI')
# (140, 'Raffaele FITTO')
# (141, 'Frances FITZGERALD')
# (142, 'Luke Ming FLANAGAN')
# (143, 'Loucas FOURLAS')
# (144, 'Emmanouil FRAGKOS')
# (145, 'Tomasz FRANKOWSKI')
# (146, 'Cindy FRANSSEN')
# (147, 'Romeo FRANZ')
# (148, 'Daniel FREUND')
# (149, 'Niels FUGLSANG')
# (150, 'Mario FURORE')
# (151, 'Michael GAHLER')
# (152, 'Lina GÁLVEZ MUÑOZ')
# (153, 'Claudia GAMON')
# (154, 'Gianna GANCIA')
# (155, 'Ibán GARCÍA DEL BLANCO')
# (156, 'José Manuel GARCÍA-MARGALLO Y MARFIL')
# (157, 'Iratxe GARCÍA PÉREZ')
# (158, 'Eider GARDIAZABAL RUBIAL')
# (159, 'Luis GARICANO')
# (160, 'Evelyne GEBHARDT')
# (161, 'Alexandra GEESE')
# (162, 'Alexis GEORGOULIS')
# (163, 'Dino GIARRUSSO')
# (164, 'Sunčana GLAVAK')
# (165, 'Raphaël GLUCKSMANN')
# (166, 'Mónica Silvana GONZÁLEZ')
# (167, 'Nicolás GONZÁLEZ CASARES')
# (168, 'Esteban GONZÁLEZ PONS')
# (169, 'Valentino GRANT')
# (170, 'Maria GRAPINI')
# (171, 'Markéta GREGOROVÁ')
# (172, 'Catherine GRISET')
# (173, 'Bart GROOTHUIS')
# (174, 'Christophe GRUDLER')
# (175, 'Francisco GUERREIRO')
# (176, 'José GUSMÃO')
# (177, 'Jytte GUTELAND')
# (178, 'Márton GYÖNGYÖSI')
# (179, 'Enikő GYŐRI')
# (180, 'Svenja HAHN')
# (181, 'Henrike HAHN')
# (182, 'Robert HAJŠEL')
# (183, 'Andrzej HALICKI')
# (184, 'Christophe HANSEN')
# (185, 'Martin HÄUSLING')
# (186, 'Valérie HAYER')
# (187, 'Anja HAZEKAMP')
# (188, 'Hannes HEIDE')
# (189, 'Krzysztof HETMAN')
# (190, 'Balázs HIDVÉGHI')
# (191, 'Monika HOHLMEIER')
# (192, 'Martin HOJSÍK')
# (193, 'Pär HOLMGREN')
# (194, 'György HÖLVÉNYI')
# (195, 'Alicia HOMS GINEL')
# (196, 'Brice HORTEFEUX')
# (197, 'Danuta Maria HÜBNER')
# (198, 'Laura HUHTASAARI')
# (199, 'Jan HUITEMA')
# (200, 'Ivars IJABS')
# (201, "Sophia in 't VELD")
# (202, 'Yannick JADOT')
# (203, 'Peter JAHR')
# (204, 'Jean-François JALKH')
# (205, 'France JAMET')
# (206, 'Lívia JÁRÓKA')
# (207, 'Adam JARUBAS')
# (208, 'Agnes JONGERIUS')
# (209, 'Virginie JORON')
# (210, 'Irena JOVEVA')
# (211, 'Rasa JUKNEVIČIENĖ')
# (212, 'Eugen JURZYCA')
# (213, 'Eva KAILI')
# (214, 'Sandra KALNIETE')
# (215, 'Radan KANEV')
# (216, 'Assita KANKO')
# (217, 'Othmar KARAS')
# (218, 'Pierre KARLESKIND')
# (219, 'Karin KARLSBRO')
# (220, 'Elsi KATAINEN')
# (221, 'Manolis KEFALOGIANNIS')
# (222, 'Fabienne KELLER')
# (223, 'Ska KELLER')
# (224, 'Seán KELLY')
# (225, 'Beata KEMPA')
# (226, 'Izabela-Helena KLOC')
# (227, 'Łukasz KOHUT')
# (228, 'Arba KOKALARI')
# (229, 'Petros KOKKALIS')
# (230, 'Marcel KOLAJA')
# (231, 'Ewa KOPACZ')
# (232, 'Moritz KÖRNER')
# (233, 'Ádám KÓSA')
# (234, 'Stelios KOULOGLOU')
# (235, 'Elena KOUNTOURA')
# (236, 'Andrey KOVATCHEV')
# (237, 'Maximilian KRAH')
# (238, 'Andrius KUBILIUS')
# (239, 'Joachim KUHS')
# (240, 'Miapetra KUMPULA-NATRI')
# (241, 'Zbigniew KUŹMIUK')
# (242, 'Stelios KYMPOUROPOULOS')
# (243, 'Georgios KYRTSOS')
# (244, 'Ilhan KYUCHYUK')
# (245, 'Jean-Lin LACAPELLE')
# (246, 'Sergey LAGODINSKY')
# (247, 'Ioannis LAGOS')
# (248, 'Aurore LALUCQ')
# (249, 'Danilo Oscar LANCINI')
# (250, 'Bernd LANGE')
# (251, 'Esther de LANGE')
# (252, 'Katrin LANGENSIEPEN')
# (253, 'Hélène LAPORTE')
# (254, 'Pierre LARROUTUROU')
# (255, 'Gilles LEBRETON')
# (256, 'Julie LECHANTEUX')
# (257, 'David LEGA')
# (258, 'Maria-Manuel LEITÃO-MARQUES')
# (259, 'Jeroen LENAERS')
# (260, 'Janusz LEWANDOWSKI')
# (261, 'Miriam LEXMANN')
# (262, 'Bogusław LIBERADZKI')
# (263, 'Peter LIESE')
# (264, 'Norbert LINS')
# (265, 'Elena LIZZI')
# (266, 'Morten LØKKEGAARD')
# (267, 'Javi LÓPEZ')
# (268, 'Juan Fernando LÓPEZ AGUILAR')
# (269, 'Leopoldo LÓPEZ GIL')
# (270, 'Antonio LÓPEZ-ISTÚRIZ WHITE')
# (271, 'César LUENA')
# (272, 'Elżbieta Katarzyna ŁUKACIJEWSKA')
# (273, 'Benoît LUTGEN')
# (274, 'David McALLISTER')
# (275, 'Mairead McGUINNESS')
# (276, 'Chris MACMANUS')
# (277, 'Jaak MADISON')
# (278, 'Cristina MAESTRE MARTÍN DE ALMAGRO')
# (279, 'Aušra MALDEIKIENĖ')
# (280, 'Adriana MALDONADO LÓPEZ')
# (281, 'Antonius MANDERS')
# (282, 'Lukas MANDL')
# (283, 'Thierry MARIANI')
# (284, 'Marian-Jean MARINESCU')
# (285, 'Erik MARQUARDT')
# (286, 'Margarida MARQUES')
# (287, 'Pedro MARQUES')
# (288, 'Fulvio MARTUSCIELLO')
# (289, 'Marisa MATIAS')
# (290, 'Predrag Fred MATIĆ')
# (291, 'Gabriel MATO')
# (292, 'Emmanuel MAUREL')
# (293, 'Costas MAVRIDES')
# (294, 'Eva MAYDELL')
# (295, 'Vangelis MEIMARAKIS')
# (296, 'Karen MELCHIOR')
# (297, 'Joëlle MÉLIN')
# (298, 'Nuno MELO')
# (299, 'Roberta METSOLA')
# (300, 'Martina MICHELS')
# (301, 'Giuseppe MILAZZO')
# (302, 'Francisco José MILLÁN MON')
# (303, 'Leszek MILLER')
# (304, 'Cláudia MONTEIRO DE AGUIAR')
# (305, 'Dolors MONTSERRAT')
# (306, 'Nadine MORANO')
# (307, 'Alessandra MORETTI')
# (308, 'Ulrike MÜLLER')
# (309, 'Siegfried MUREŞAN')
# (310, 'Caroline NAGTEGAAL')
# (311, 'Victor NEGRESCU')
# (312, 'Hannah NEUMANN')
# (313, 'Angelika NIEBLER')
# (314, 'Luděk NIEDERMAYER')
# (315, 'Ville NIINISTÖ')
# (316, 'Ljudmila NOVAK')
# (317, 'Andrey NOVAKOV')
# (318, 'Janina OCHOJSKA')
# (319, 'Jan-Christoph OETJEN')
# (320, 'Jan OLBRYCHT')
# (321, 'Younous OMARJEE')
# (322, "Grace O'SULLIVAN")
# (323, 'Urmas PAET')
# (324, 'Alessandro PANZA')
# (325, 'Dimitrios PAPADIMOULIS')
# (326, 'Aldo PATRICIELLO')
# (327, 'Jutta PAULUS')
# (328, 'Piernicola PEDICINI')
# (329, 'Kris PEETERS')
# (330, 'Mikuláš PEKSA')
# (331, 'Lídia PEREIRA')
# (332, 'Kira Marie PETER-HANSEN')
# (333, 'Morten PETERSEN')
# (334, 'Pina PICIERNO')
# (335, 'Tonino PICULA')
# (336, 'Markus PIEPER')
# (337, 'Sirpa PIETIKÄINEN')
# (338, 'Sabrina PIGNEDOLI')
# (339, 'Manu PINEDA')
# (340, 'Kati PIRI')
# (341, 'Giuliano PISAPIA')
# (342, 'Stanislav POLČÁK')
# (343, 'Jessica POLFJÄRD')
# (344, 'Clara PONSATÍ OBIOLS')
# (345, 'Jiří POSPÍŠIL')
# (346, 'Carles PUIGDEMONT I CASAMAJÓ')
# (347, 'Emil RADEV')
# (348, 'Dennis RADTKE')
# (349, 'Elżbieta RAFALSKA')
# (350, 'Paulo RANGEL')
# (351, 'Evelyn REGNER')
# (352, 'Sira REGO')
# (353, 'Terry REINTKE')
# (354, 'Karlo RESSLER')
# (355, 'Diana RIBA I GINER')
# (356, 'Frédérique RIES')
# (357, 'Antonio Maria RINALDI')
# (358, 'Dominique RIQUET')
# (359, 'Jérôme RIVIÈRE')
# (360, 'Inma RODRÍGUEZ-PIÑERO')
# (361, 'María Soraya RODRÍGUEZ RAMOS')
# (362, 'Sándor RÓNAI')
# (363, 'Daniela RONDINELLI')
# (364, 'Rob ROOKEN')
# (365, 'Dorien ROOKMAKER')
# (366, 'Robert ROOS')
# (367, 'Caroline ROOSE')
# (368, 'Marcos ROS SEMPERE')
# (369, 'Bert-Jan RUISSEN')
# (370, 'Domènec RUIZ DEVESA')
# (371, 'Bogdan RZOŃCA')
# (372, 'Massimiliano SALINI')
# (373, 'Nacho SÁNCHEZ AMOR')
# (374, 'Anne SANDER')
# (375, 'Alfred SANT')
# (376, 'Silvia SARDONE')
# (377, 'Petri SARVAMAA')
# (378, 'Mounir SATOURI')
# (379, 'Christel SCHALDEMOSE')
# (380, 'Andreas SCHIEDER')
# (381, 'Christine SCHNEIDER')
# (382, 'Helmut SCHOLZ')
# (383, 'Annie SCHREIJER-PIERIK')
# (384, 'Liesje SCHREINEMACHER')
# (385, 'Sven SCHULZE')
# (386, 'Andreas SCHWAB')
# (387, 'Stéphane SÉJOURNÉ')
# (388, 'Monica SEMEDO')
# (389, 'Nico SEMSROTT')
# (390, 'Radosław SIKORSKI')
# (391, 'Michal ŠIMEČKA')
# (392, 'Sven SIMON')
# (393, 'Birgit SIPPEL')
# (394, 'Sara SKYTTEDAL')
# (395, 'Massimiliano SMERIGLIO')
# (396, 'Michaela ŠOJDROVÁ')
# (397, 'Tomislav SOKOL')
# (398, 'Jordi SOLÉ')
# (399, 'Susana SOLÍS PÉREZ')
# (400, 'Martin SONNEBORN')
# (401, 'Sylwia SPUREK')
# (402, 'Maria SPYRAKI')
# (403, 'Sergei STANISHEV')
# (404, 'Ivan ŠTEFANEC')
# (405, 'Nicolae ŞTEFĂNUȚĂ')
# (406, 'Tineke STRIK')
# (407, 'Ramona STRUGARIU')
# (408, 'Beata SZYDŁO')
# (409, 'Linea SØGAARD-LIDELL')
# (410, 'Antonio TAJANI')
# (411, 'Paul TANG')
# (412, 'Marc TARABELLA')
# (413, 'Dominik TARCZYŃSKI')
# (414, 'Annalisa TARDINO')
# (415, 'Vera TAX')
# (416, 'Hermann TERTSCH')
# (417, 'Barbara THALER')
# (418, 'Róża THUN UND HOHENSTEIN')
# (419, 'Irene TINAGLI')
# (420, 'Tomas TOBÉ')
# (421, 'Patrizia TOIA')
# (422, 'Ruža TOMAŠIĆ')
# (423, 'Romana TOMC')
# (424, 'Yana TOOM')
# (425, 'Nils TORVALDS')
# (426, 'Edina TÓTH')
# (427, 'Marie TOUSSAINT')
# (428, 'László TRÓCSÁNYI')
# (429, 'István UJHELYI')
# (430, 'Miguel URBÁN CRESPO')
# (431, 'Ernest URTASUN')
# (432, 'Inese VAIDERE')
# (433, 'Kim VAN SPARRENTAK')
# (434, 'Hilde VAUTMANS')
# (435, 'Marie-Pierre VEDRENNE')
# (436, 'Sabine VERHEYEN')
# (437, 'Guy VERHOFSTADT')
# (438, 'Idoia VILLANUEVA RUIZ')
# (439, 'Nikolaj VILLUMSEN')
# (440, 'Loránt VINCZE')
# (441, 'Marianne VIND')
# (442, 'Henna VIRKKUNEN')
# (443, 'Viola VON CRAMON-TAUBADEL')
# (444, 'Alexandr VONDRA')
# (445, 'Axel VOSS')
# (446, 'Elissavet VOZEMBERG-VRIONIDI')
# (447, 'Veronika VRECIONOVÁ')
# (448, 'Lucia VUOLO')
# (449, 'Adrián VÁZQUEZ LÁZARA')
# (450, 'Mick WALLACE')
# (451, 'Maria WALSH')
# (452, 'Marion WALSMANN')
# (453, 'Jörgen WARBORN')
# (454, 'Witold Jan WASZCZYKOWSKI')
# (455, 'Manfred WEBER')
# (456, 'Charlie WEIMERS')
# (457, 'Pernille WEISS')
# (458, 'Iuliu WINKLER')
# (459, 'Angelika WINZIG')
# (460, 'Isabel WISELER-LIMA')
# (461, 'Jadwiga WIŚNIEWSKA')
# (462, 'Tiemo WÖLKEN')
# (463, 'Lara WOLTERS')
# (464, 'Stéphanie YON-COURTIN')
# (465, 'Jan ZAHRADIL')
# (466, 'Marco ZANNI')
# (467, 'Javier ZARZALEJOS')
# (468, 'Tatjana ŽDANOKA')
# (469, 'Tomáš ZDECHOVSKÝ')
# (470, 'Kosma ZŁOTOWSKI')
# (471, 'Juan Ignacio ZOIDO ÁLVAREZ')
# (472, 'Carlos ZORRINHO')
# (473, 'Željana ZOVKO')
# (474, 'Milan ZVER')

# %%
df.name.unique()
# Out:
# array(['Magdalena ADAMOWICZ', 'Asim ADEMOV', 'Isabella ADINOLFI',
#        'Clara AGUILERA', 'Alviina ALAMETSÄ', 'Abir AL-SAHLANI',
#        'Andris AMERIKS', 'Christine ANDERSON', 'Rasmus ANDRESEN',
#        'Eric ANDRIEU', 'Nikos ANDROULAKIS', 'Marc ANGEL', 'Andrus ANSIP',
#        'Maria ARENA', 'Pascal ARIMONT', 'Bartosz ARŁUKOWICZ',
#        'Clotilde ARMAND', 'Anna-Michelle ASIMAKOPOULOU', 'Manon AUBRY',
#        'Margrete AUKEN', 'Petras AUŠTREVIČIUS', 'Malik AZMANI',
#        'Marek Paweł BALT', 'Jordan BARDELLA', 'Katarina BARLEY',
#        'Pernando BARRENA ARZA', 'Traian BĂSESCU', 'José Ramón BAUZÁ DÍAZ',
#        'Nicolas BAY', 'Nicola BEER', 'Tiziana BEGHIN', 'Aurelia BEIGNEUX',
#        'François-Xavier BELLAMY', 'Brando BENIFEI',
#        'Isabel BENJUMEA BENJUMEA', 'Hildegard BENTELE', 'Tom BERENDSEN',
#        'Lars Patrick BERG', 'Stefan BERGER', 'Sergio BERLATO',
#        'Silvio BERLUSCONI', 'Robert BIEDROŃ', 'Adam BIELAN',
#        'Izaskun BILBAO BARANDICA', 'Vladimír BILČÍK', 'Dominique BILDE',
#        'Benoît BITEAU', 'Malin BJÖRK', 'Michael BLOSS', 'Andrea BOCSKOR',
#        'Damian BOESELAGER', 'Franc BOGOVIČ', 'Manuel BOMPARD',
#        'Simona BONAFÈ', 'Paolo BORCHIA', 'Biljana BORZAN', 'Marc BOTENGA',
#        'Gilles BOYER', 'Patrick BREYER', 'Saskia BRICMONT',
#        'Joachim Stanisław BRUDZIŃSKI', 'Annika BRUNA', 'Sylvie BRUNET',
#        'Daniel BUDA', 'Delara BURKHARDT', 'Martin BUSCHMANN',
#        'Jorge BUXADÉ VILLALBA', 'Jerzy BUZEK', 'Marco CAMPOMENOSI',
#        'Jordi CAÑAS', 'Pascal CANFIN', 'Damien CARÊME', 'Andrea CAROPPO',
#        'Isabel CARVALHAIS', 'Maria da Graça CARVALHO', 'David CASA',
#        'Daniel CASPARY', 'Fabio Massimo CASTALDO',
#        'Pilar del CASTILLO VERA', 'Anna CAVAZZINI', 'Sara CERDAS',
#        'Catherine CHABAUD', 'Mohammed CHAHIM', 'Leila CHAIBI',
#        'Caterina CHINNICI', 'Lefteris CHRISTOFOROU', 'Ilana CICUREL',
#        'Deirdre CLUNE', 'Nathalie COLIN-OESTERLÉ', 'Gilbert COLLARD',
#        'Antoni COMÍN I OLIVERES', 'David CORMAND', 'Ignazio CORRAO',
#        'Andrea COZZOLINO', 'Katalin CSEH', 'Ciarán CUFFE',
#        'Josianne CUTAJAR', 'Ryszard CZARNECKI', 'Peter van DALEN',
#        'Miriam DALLI', 'Jakop G. DALUNDE', "Rosa D'AMATO",
#        'Arnaud DANJEAN', 'Nicola DANTI', 'Salvatore DE MEO',
#        'Paolo DE CASTRO', 'Gwendoline DELBOS-CORFIELD', 'Andor DELI',
#        'Karima DELLI', 'Özlem DEMIREL', 'Petra DE SUTTER',
#        'Tamás DEUTSCH', 'Geoffroy DIDIER', 'Martina DLABAJOVÁ',
#        'Christian DOLESCHAL', 'Anna Júlia DONÁTH', 'Francesca DONATO',
#        'Herbert DORFMANN', 'Marco DREOSTO', 'Jarosław DUDA',
#        'Estrella DURÁ FERRANDIS', 'Lucia ĎURIŠ NICHOLSONOVÁ',
#        'Angel DZHAMBAZKI', 'Bas EICKHOUT', 'Derk Jan EPPINK',
#        'Cornelia ERNST', 'Ismail ERTUG', 'Eleonora EVI', 'Agnès EVREN',
#        'Tanja FAJON', 'Laurence FARRENG', 'Fredrick FEDERLEY',
#        'Markus FERBER', 'José Manuel FERNANDES', 'Jonás FERNÁNDEZ',
#        'Giuseppe FERRANDINO', 'Laura FERRARA', 'João FERREIRA',
#        'Carlo FIDANZA', 'Pietro FIOCCHI', 'Raffaele FITTO',
#        'Frances FITZGERALD', 'Luke Ming FLANAGAN', 'Loucas FOURLAS',
#        'Emmanouil FRAGKOS', 'Tomasz FRANKOWSKI', 'Cindy FRANSSEN',
#        'Romeo FRANZ', 'Daniel FREUND', 'Niels FUGLSANG', 'Mario FURORE',
#        'Michael GAHLER', 'Lina GÁLVEZ MUÑOZ', 'Claudia GAMON',
#        'Gianna GANCIA', 'Ibán GARCÍA DEL BLANCO',
#        'José Manuel GARCÍA-MARGALLO Y MARFIL', 'Iratxe GARCÍA PÉREZ',
#        'Eider GARDIAZABAL RUBIAL', 'Luis GARICANO', 'Evelyne GEBHARDT',
#        'Alexandra GEESE', 'Alexis GEORGOULIS', 'Dino GIARRUSSO',
#        'Sunčana GLAVAK', 'Raphaël GLUCKSMANN', 'Mónica Silvana GONZÁLEZ',
#        'Nicolás GONZÁLEZ CASARES', 'Esteban GONZÁLEZ PONS',
#        'Valentino GRANT', 'Maria GRAPINI', 'Markéta GREGOROVÁ',
#        'Catherine GRISET', 'Bart GROOTHUIS', 'Christophe GRUDLER',
#        'Francisco GUERREIRO', 'José GUSMÃO', 'Jytte GUTELAND',
#        'Márton GYÖNGYÖSI', 'Enikő GYŐRI', 'Svenja HAHN', 'Henrike HAHN',
#        'Robert HAJŠEL', 'Andrzej HALICKI', 'Christophe HANSEN',
#        'Martin HÄUSLING', 'Valérie HAYER', 'Anja HAZEKAMP',
#        'Hannes HEIDE', 'Krzysztof HETMAN', 'Balázs HIDVÉGHI',
#        'Monika HOHLMEIER', 'Martin HOJSÍK', 'Pär HOLMGREN',
#        'György HÖLVÉNYI', 'Alicia HOMS GINEL', 'Brice HORTEFEUX',
#        'Danuta Maria HÜBNER', 'Laura HUHTASAARI', 'Jan HUITEMA',
#        'Ivars IJABS', "Sophia in 't VELD", 'Yannick JADOT', 'Peter JAHR',
#        'Jean-François JALKH', 'France JAMET', 'Lívia JÁRÓKA',
#        'Adam JARUBAS', 'Agnes JONGERIUS', 'Virginie JORON',
#        'Irena JOVEVA', 'Rasa JUKNEVIČIENĖ', 'Eugen JURZYCA', 'Eva KAILI',
#        'Sandra KALNIETE', 'Radan KANEV', 'Assita KANKO', 'Othmar KARAS',
#        'Pierre KARLESKIND', 'Karin KARLSBRO', 'Elsi KATAINEN',
#        'Manolis KEFALOGIANNIS', 'Fabienne KELLER', 'Ska KELLER',
#        'Seán KELLY', 'Beata KEMPA', 'Izabela-Helena KLOC', 'Łukasz KOHUT',
#        'Arba KOKALARI', 'Petros KOKKALIS', 'Marcel KOLAJA', 'Ewa KOPACZ',
#        'Moritz KÖRNER', 'Ádám KÓSA', 'Stelios KOULOGLOU',
#        'Elena KOUNTOURA', 'Andrey KOVATCHEV', 'Maximilian KRAH',
#        'Andrius KUBILIUS', 'Joachim KUHS', 'Miapetra KUMPULA-NATRI',
#        'Zbigniew KUŹMIUK', 'Stelios KYMPOUROPOULOS', 'Georgios KYRTSOS',
#        'Ilhan KYUCHYUK', 'Jean-Lin LACAPELLE', 'Sergey LAGODINSKY',
#        'Ioannis LAGOS', 'Aurore LALUCQ', 'Danilo Oscar LANCINI',
#        'Bernd LANGE', 'Esther de LANGE', 'Katrin LANGENSIEPEN',
#        'Hélène LAPORTE', 'Pierre LARROUTUROU', 'Gilles LEBRETON',
#        'Julie LECHANTEUX', 'David LEGA', 'Maria-Manuel LEITÃO-MARQUES',
#        'Jeroen LENAERS', 'Janusz LEWANDOWSKI', 'Miriam LEXMANN',
#        'Bogusław LIBERADZKI', 'Peter LIESE', 'Norbert LINS',
#        'Elena LIZZI', 'Morten LØKKEGAARD', 'Javi LÓPEZ',
#        'Juan Fernando LÓPEZ AGUILAR', 'Leopoldo LÓPEZ GIL',
#        'Antonio LÓPEZ-ISTÚRIZ WHITE', 'César LUENA',
#        'Elżbieta Katarzyna ŁUKACIJEWSKA', 'Benoît LUTGEN',
#        'David McALLISTER', 'Mairead McGUINNESS', 'Chris MACMANUS',
#        'Jaak MADISON', 'Cristina MAESTRE MARTÍN DE ALMAGRO',
#        'Aušra MALDEIKIENĖ', 'Adriana MALDONADO LÓPEZ', 'Antonius MANDERS',
#        'Lukas MANDL', 'Thierry MARIANI', 'Marian-Jean MARINESCU',
#        'Erik MARQUARDT', 'Margarida MARQUES', 'Pedro MARQUES',
#        'Fulvio MARTUSCIELLO', 'Marisa MATIAS', 'Predrag Fred MATIĆ',
#        'Gabriel MATO', 'Emmanuel MAUREL', 'Costas MAVRIDES',
#        'Eva MAYDELL', 'Vangelis MEIMARAKIS', 'Karen MELCHIOR',
#        'Joëlle MÉLIN', 'Nuno MELO', 'Roberta METSOLA', 'Martina MICHELS',
#        'Giuseppe MILAZZO', 'Francisco José MILLÁN MON', 'Leszek MILLER',
#        'Cláudia MONTEIRO DE AGUIAR', 'Dolors MONTSERRAT', 'Nadine MORANO',
#        'Alessandra MORETTI', 'Ulrike MÜLLER', 'Siegfried MUREŞAN',
#        'Caroline NAGTEGAAL', 'Victor NEGRESCU', 'Hannah NEUMANN',
#        'Angelika NIEBLER', 'Luděk NIEDERMAYER', 'Ville NIINISTÖ',
#        'Ljudmila NOVAK', 'Andrey NOVAKOV', 'Janina OCHOJSKA',
#        'Jan-Christoph OETJEN', 'Jan OLBRYCHT', 'Younous OMARJEE',
#        "Grace O'SULLIVAN", 'Urmas PAET', 'Alessandro PANZA',
#        'Dimitrios PAPADIMOULIS', 'Aldo PATRICIELLO', 'Jutta PAULUS',
#        'Piernicola PEDICINI', 'Kris PEETERS', 'Mikuláš PEKSA',
#        'Lídia PEREIRA', 'Kira Marie PETER-HANSEN', 'Morten PETERSEN',
#        'Pina PICIERNO', 'Tonino PICULA', 'Markus PIEPER',
#        'Sirpa PIETIKÄINEN', 'Sabrina PIGNEDOLI', 'Manu PINEDA',
#        'Kati PIRI', 'Giuliano PISAPIA', 'Stanislav POLČÁK',
#        'Jessica POLFJÄRD', 'Clara PONSATÍ OBIOLS', 'Jiří POSPÍŠIL',
#        'Carles PUIGDEMONT I CASAMAJÓ', 'Emil RADEV', 'Dennis RADTKE',
#        'Elżbieta RAFALSKA', 'Paulo RANGEL', 'Evelyn REGNER', 'Sira REGO',
#        'Terry REINTKE', 'Karlo RESSLER', 'Diana RIBA I GINER',
#        'Frédérique RIES', 'Antonio Maria RINALDI', 'Dominique RIQUET',
#        'Jérôme RIVIÈRE', 'Inma RODRÍGUEZ-PIÑERO',
#        'María Soraya RODRÍGUEZ RAMOS', 'Sándor RÓNAI',
#        'Daniela RONDINELLI', 'Rob ROOKEN', 'Dorien ROOKMAKER',
#        'Robert ROOS', 'Caroline ROOSE', 'Marcos ROS SEMPERE',
#        'Bert-Jan RUISSEN', 'Domènec RUIZ DEVESA', 'Bogdan RZOŃCA',
#        'Massimiliano SALINI', 'Nacho SÁNCHEZ AMOR', 'Anne SANDER',
#        'Alfred SANT', 'Silvia SARDONE', 'Petri SARVAMAA',
#        'Mounir SATOURI', 'Christel SCHALDEMOSE', 'Andreas SCHIEDER',
#        'Christine SCHNEIDER', 'Helmut SCHOLZ', 'Annie SCHREIJER-PIERIK',
#        'Liesje SCHREINEMACHER', 'Sven SCHULZE', 'Andreas SCHWAB',
#        'Stéphane SÉJOURNÉ', 'Monica SEMEDO', 'Nico SEMSROTT',
#        'Radosław SIKORSKI', 'Michal ŠIMEČKA', 'Sven SIMON',
#        'Birgit SIPPEL', 'Sara SKYTTEDAL', 'Massimiliano SMERIGLIO',
#        'Michaela ŠOJDROVÁ', 'Tomislav SOKOL', 'Jordi SOLÉ',
#        'Susana SOLÍS PÉREZ', 'Martin SONNEBORN', 'Sylwia SPUREK',
#        'Maria SPYRAKI', 'Sergei STANISHEV', 'Ivan ŠTEFANEC',
#        'Nicolae ŞTEFĂNUȚĂ', 'Tineke STRIK', 'Ramona STRUGARIU',
#        'Beata SZYDŁO', 'Linea SØGAARD-LIDELL', 'Antonio TAJANI',
#        'Paul TANG', 'Marc TARABELLA', 'Dominik TARCZYŃSKI',
#        'Annalisa TARDINO', 'Vera TAX', 'Hermann TERTSCH',
#        'Barbara THALER', 'Róża THUN UND HOHENSTEIN', 'Irene TINAGLI',
#        'Tomas TOBÉ', 'Patrizia TOIA', 'Ruža TOMAŠIĆ', 'Romana TOMC',
#        'Yana TOOM', 'Nils TORVALDS', 'Edina TÓTH', 'Marie TOUSSAINT',
#        'László TRÓCSÁNYI', 'István UJHELYI', 'Miguel URBÁN CRESPO',
#        'Ernest URTASUN', 'Inese VAIDERE', 'Kim VAN SPARRENTAK',
#        'Hilde VAUTMANS', 'Marie-Pierre VEDRENNE', 'Sabine VERHEYEN',
#        'Guy VERHOFSTADT', 'Idoia VILLANUEVA RUIZ', 'Nikolaj VILLUMSEN',
#        'Loránt VINCZE', 'Marianne VIND', 'Henna VIRKKUNEN',
#        'Viola VON CRAMON-TAUBADEL', 'Alexandr VONDRA', 'Axel VOSS',
#        'Elissavet VOZEMBERG-VRIONIDI', 'Veronika VRECIONOVÁ',
#        'Lucia VUOLO', 'Adrián VÁZQUEZ LÁZARA', 'Mick WALLACE',
#        'Maria WALSH', 'Marion WALSMANN', 'Jörgen WARBORN',
#        'Witold Jan WASZCZYKOWSKI', 'Manfred WEBER', 'Charlie WEIMERS',
#        'Pernille WEISS', 'Iuliu WINKLER', 'Angelika WINZIG',
#        'Isabel WISELER-LIMA', 'Jadwiga WIŚNIEWSKA', 'Tiemo WÖLKEN',
#        'Lara WOLTERS', 'Stéphanie YON-COURTIN', 'Jan ZAHRADIL',
#        'Marco ZANNI', 'Javier ZARZALEJOS', 'Tatjana ŽDANOKA',
#        'Tomáš ZDECHOVSKÝ', 'Kosma ZŁOTOWSKI',
#        'Juan Ignacio ZOIDO ÁLVAREZ', 'Carlos ZORRINHO', 'Željana ZOVKO',
#        'Milan ZVER'], dtype=object)

# %%
key_femme = [0, 2, 3, 4, 7, 13, 16, 17, 18 , 19, 24, 30, 31, 34, 35, 43, 45, 47, 49, 53, 55, 59, 61, 62, 64,\
             73, 74, 79, 80, 81, 83, 84, 86, 87, 88, 94, 96, 99, 101, 106, 108, 109, 110, 113, 115, 116, 120, 121, 125, 127, 128, 129, 130,\
            136, 141, 146, 152, 153, 154, 157, 160, 161, 164, 166, 170, 171, 172, 177, 180, 186,\
            187, 188, 191, 195, 197, 198, 201, 205, 206, 208, 209, 210, 211, 213, 214, 216, 219, 220, 222,\
            223, 225, 226, 228, 231, 235, 240, 248, 251, 252, 253, 256, 258, 261, 265, 272, 275, 278, 279, 280,\
            286, 289, 294, 296, 297, 299, 300, 304, 305, 306, 307, 310, 312, 313, 316, 318, 322, 327, 331, 332, 334,\
            337, 338, 340, 343, 343, 344, 349, 351, 352, 355, 356, 360, 361, 363, 365, 367, 374, 376, 379, 381, 383, 384,\
            388, 393, 394, 396, 399, 401, 402, 406, 407, 408, 409, 414, 415, 417, 418, 419, 421, 422, 423, 424, 426, 427,\
            432, 433, 434, 435, 436, 438, 441, 442, 443, 446, 447, 448, 451, 452, 457, 458, 459, 460, 461, 463, 464, 468, 473]

# %%
data = df.copy()
data['sex'] = 0

# %%
for key in key_femme:
    data['sex'][key]  =1
# Out:
# /home/conte/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data
# Out:
#      mep_id                        name   country  \
# 0    197490         Magdalena ADAMOWICZ    Poland
# 1    189525                 Asim ADEMOV  Bulgaria
# 2    124831           Isabella ADINOLFI     Italy
# 3    125045              Clara AGUILERA     Spain
# 4    204335            Alviina ALAMETSÄ   Finland
# ..      ...                         ...       ...
# 470  124884             Kosma ZŁOTOWSKI    Poland
# 471  197621  Juan Ignacio ZOIDO ÁLVAREZ     Spain
# 472  124739             Carlos ZORRINHO  Portugal
# 473  185341               Željana ZOVKO   Croatia
# 474   96933                  Milan ZVER  Slovenia
#
#                                                  group  \
# 0    Group of the European People's Party (Christia...
# 1    Group of the European People's Party (Christia...
# 2                                 Non-attached Members
# 3    Group of the Progressive Alliance of Socialist...
# 4           Group of the Greens/European Free Alliance
# ..                                                 ...
# 470        European Conservatives and Reformists Group
# 471  Group of the European People's Party (Christia...
# 472  Group of the Progressive Alliance of Socialist...
# 473  Group of the European People's Party (Christia...
# 474  Group of the European People's Party (Christia...
#
#                                          nat_group          twitter  \
# 0                                      Independent  Adamowicz_Magda
# 1    Citizens for European Development of Bulgaria       AdemovAsim
# 2                               Movimento 5 Stelle     Isa_Adinolfi
# 3                Partido Socialista Obrero Español   ClaraAguilera7
# 4                                    Vihreä liitto  alviinaalametsa
# ..                                             ...              ...
# 470                         Prawo i Sprawiedliwość   KosmaZlotowski
# 471                                Partido Popular          zoidoji
# 472                             Partido Socialista        czorrinho
# 473                 Hrvatska demokratska zajednica          ZovkoEU
# 474                  Slovenska demokratska stranka        MilanZver
#
#                                                content  sex
# 0    [@danutahuebner Bardzo dziękuję @danutahuebner...    1
# 1    [135 години единна и силна България. \nЧестит ...    0
# 2    [Sembra un film, ma purtroppo è realtà: le imm...    1
# 3    [Clara Aguilera: "El criterio científico debe ...    1
# 4    [@LHurttila @MariaOhisalo Kaupungilla on järje...    1
# ..                                                 ...  ...
# 470  [https://t.co/7NnVzDXmis, Dziś inauguracja!\nh...    0
# 471  [Desde @ppegrupo reclamamos una mayor segurida...    0
# 472  [@sofiaferreira57 O meu mail profissional é pú...    0
# 473  [Svim učenicima, a naročito prvašićima te njih...    1
# 474  [Genialno! https://t.co/7L2cpVkVJn, “@Europarl...    0
#
# [475 rows x 8 columns]
