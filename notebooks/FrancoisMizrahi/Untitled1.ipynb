# %%
import pandas as pd

# %%
df = pd.read_pickle("../../raw_data/tweets_en.pkl")

# %%
df.head(2)
# Out:
#    mep_id                 name country  \
# 0  197490  Magdalena ADAMOWICZ  Poland
# 1  197490  Magdalena ADAMOWICZ  Poland
#
#                                                group    nat_group  \
# 0  Group of the European People's Party (Christia...  Independent
# 1  Group of the European People's Party (Christia...  Independent
#
#            twitter                                            content
# 0  Adamowicz_Magda  thank you very much free media independent of ...
# 1  Adamowicz_Magda  the commission has adopted major pilot project...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_validate

forest = RandomForestRegressor()

forest_cv = cross_validate(forest, 
                            df[['country','name','nat_group', 'content']],
                            df['group'],
                            scoring = "r2",
                            cv=10)

forest_cv['test_score']
# Out:
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Italy'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# /Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 304, in fit
#     accept_sparse="csc", dtype=DTYPE)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/pandas/core/generic.py", line 1778, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "/Users/francoismizrahi/.pyenv/versions/3.7.7/envs/delphes/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'Poland'
#
#   FitFailedWarning)
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])
