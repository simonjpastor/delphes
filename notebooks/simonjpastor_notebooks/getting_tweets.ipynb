# %% [markdown]
# # Vectoring Tweets

# %%
import pandas as pd
import numpy as np
import io
from googletrans import Translator, LANGUAGES
from time import sleep
import string

# %% [markdown]
# ## Embedding dict

# %%
def load_vec(emb_path, nmax=50000):
    vectors = []
    word2id = {}
    with io.open(emb_path, 'r', encoding='utf-8', newline='\n', errors='ignore') as f:
        next(f)
        for i, line in enumerate(f):
            word, vect = line.rstrip().split(' ', 1)
            vect = np.fromstring(vect, sep=' ')
            assert word not in word2id, 'word found twice'
            vectors.append(vect)
            word2id[word] = len(word2id)
            if len(word2id) == nmax:
                break
    id2word = {v: k for k, v in word2id.items()}
    embeddings = np.vstack(vectors)
    return embeddings, id2word, word2id

# %% [markdown]
# **Select Languages**

# %%
languages = ["bulgarian","english"]

# %%
df
# Out:
#         mep_id              name   country  \
# 300     189525       Asim ADEMOV  Bulgaria
# 301     189525       Asim ADEMOV  Bulgaria
# 302     189525       Asim ADEMOV  Bulgaria
# 303     189525       Asim ADEMOV  Bulgaria
# 304     189525       Asim ADEMOV  Bulgaria
# ...        ...               ...       ...
# 116554  124852  Sergei STANISHEV  Bulgaria
# 116555  124852  Sergei STANISHEV  Bulgaria
# 116556  124852  Sergei STANISHEV  Bulgaria
# 116557  124852  Sergei STANISHEV  Bulgaria
# 116558  124852  Sergei STANISHEV  Bulgaria
#
#                                                     group  \
# 300     Group of the European People's Party (Christia...
# 301     Group of the European People's Party (Christia...
# 302     Group of the European People's Party (Christia...
# 303     Group of the European People's Party (Christia...
# 304     Group of the European People's Party (Christia...
# ...                                                   ...
# 116554  Group of the Progressive Alliance of Socialist...
# 116555  Group of the Progressive Alliance of Socialist...
# 116556  Group of the Progressive Alliance of Socialist...
# 116557  Group of the Progressive Alliance of Socialist...
# 116558  Group of the Progressive Alliance of Socialist...
#
#                                             nat_group          twitter  \
# 300     Citizens for European Development of Bulgaria       AdemovAsim
# 301     Citizens for European Development of Bulgaria       AdemovAsim
# 302     Citizens for European Development of Bulgaria       AdemovAsim
# 303     Citizens for European Development of Bulgaria       AdemovAsim
# 304     Citizens for European Development of Bulgaria       AdemovAsim
# ...                                               ...              ...
# 116554                      Bulgarian Socialist Party  SergeiStanishev
# 116555                      Bulgarian Socialist Party  SergeiStanishev
# 116556                      Bulgarian Socialist Party  SergeiStanishev
# 116557                      Bulgarian Socialist Party  SergeiStanishev
# 116558                      Bulgarian Socialist Party  SergeiStanishev
#
#                                                   content
# 300     135 години единна и силна България. \nЧестит п...
# 301     📢 Остана 1⃣ седмица! Предимствата да станете с...
# 302     -@AdemovAsim ГЕРБ/ЕНП: Познавайки добре обстан...
# 303     Въпреки че се появиха неканени на срещата на Г...
# 304     Д-р Даниела Дариткова е прекрасен Човек и изкл...
# ...                                                   ...
# 116554  We unveil our #WesternBalkans strategy which i...
# 116555  Journalist: Will the European Parliament stick...
# 116556  "We are advocating for #TransnationalLists and...
# 116557  #Croatia PM @AndrejPlenkovic in #EPlenary toda...
# 116558  Да му дадеме на светот еден нов Балкан, во кој...
#
# [2636 rows x 7 columns]

# %% [markdown]
# **Select path to languages embedding txt**

# %%
nmax = 100000  # maximum number of word embeddings to load
emb_dict = {}
for lang in languages:
    path = f"../../raw_data/vectors_{lang}.txt" #Select here
    embeddings, id2word, word2id = load_vec(path, nmax)
    emb_dict[lang] = [embeddings, id2word, word2id]

# %%
def multilang_word_vector(word, emb_dict, lang=None):
    translator = Translator()
    if lang == None: lang = LANGUAGES[translator.detect(word).lang]
    lang_val = LANGUAGES.values()
    if lang in lang_val and lang in emb_dict.keys():
        if word in emb_dict.get(lang)[2].keys():
            return emb_dict[lang][0][emb_dict[lang][2][word]]
    return False

# %%
def vect_tweet(tweet):
    print(f"{nw_df.content[nw_df.content == tweet].index[0]/len(nw_df.content)*100:.2f}%")
    translator = Translator()
    if translator.detect(tweet).lang in LANGUAGES.keys():
        lang = LANGUAGES[translator.detect(tweet).lang]
        words = tweet.split(" ")
        res = []
        for i in words:
            res.append(multilang_word_vector(i, emb_dict, lang))
        return res
    return None

# %% [markdown]
# **Select path to df**

# %%
df_full = pd.read_pickle("../../delphes/data/extended_tweet_df")

# %%
df_full["country"].unique()
# Out:
# array(['Poland', 'Bulgaria', 'Italy', 'Spain', 'Finland', 'Sweden',
#        'Latvia', 'Germany', 'Greece', 'Luxembourg', 'Estonia', 'Belgium',
#        'Romania', 'France', 'Denmark', 'Lithuania', 'Netherlands',
#        'Slovakia', 'Hungary', 'Slovenia', 'Croatia', 'Portugal', 'Malta',
#        'Cyprus', 'Ireland', 'Czechia', 'Austria'], dtype=object)

# %% [markdown]
# **Select countries including the first value**

# %%
df = df_full[df_full["country"] == "Bulgaria"]
#for i in ["Denmark"]:
    #df = pd.concat([df, df_full[df_full["country"] == i]])

# %%
df.country.unique()
# Out:
# array(['Bulgaria'], dtype=object)

# %% [markdown]
# ## Data clean

# %%
def rmurl_df(df, column_name):
    '''
    This function removes all the URLs, the #hashtag and the @user of a column made of strings.
    Be careful to apply it BEFORE all the other preprocessing steps (if not it wont'
    be recognized as a URL)
    '''
    df = df.copy()
    df[column_name] = df[column_name].str.replace('http\S+|www.\S+|@\S+|#\S+', '', case=False)
    return df

# %%
def lower_df(df, column_name):
    '''
    This function lowercases a column made of strings and return the dataframe.
    '''
    df = df.copy()
    df[column_name] = df[column_name].str.lower()
    return df

# %%
def rmnumbers_df(df, column_name):
    '''
    This function removes all the digits of a column made of strings.
    '''
    df = df.copy()
    def remove_numbers(text):
        return ''.join(word for word in text if not word.isdigit())
    df[column_name] = df[column_name].apply(remove_numbers)
    return df

# %%
def rmpunct_df(df, column_name):
    '''
    This function removes all the punctuations, all the "rt" and remove multiple spaces
    of a column made of strings.
    '''
    punct = string.punctuation
    df = df.copy()
    def replace_punct(text):
        for punctu in punct:
            text = text.replace(punctu, ' ')
            text = text.replace(' rt ','')
            text = " ".join(text.split())
        return text
    df[column_name] = df[column_name].apply(replace_punct)
    return df

# %%
def rmemojis_df(df):
    '''
    This function removes all the emojis of a column made of strings.
    Be careful to translate in latin alphabet before applying this function :
    it also removes cyrillic alphabet.
    '''
    df = df.copy()
    df = df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
    return df

# %%
nw_df = rmurl_df(df, "content")
nw_df = lower_df(nw_df, "content")
nw_df = rmnumbers_df(nw_df, "content")
nw_df = rmpunct_df(nw_df, "content")
nw_df = rmemojis_df(nw_df)

# %% [markdown]
# ## Vector

# %%
emb_dict.keys()
# Out:
# dict_keys(['bulgarian', 'english'])

# %%
nw_df.content[2:3]
# Out:
# 302
# Name: content, dtype: object

# %%
vecs = nw_df.content[:].map(vect_tweet)
# Out:
# 11.38%
# 11.42%
# 11.46%
# 11.49%
# 11.53%
# 11.57%
# 11.61%
# 11.65%
# 11.68%
# 11.72%
# 11.76%
# 11.80%
# 11.42%
# 11.87%
# 11.91%
# 11.95%
# 11.99%
# 12.03%
# 12.06%
# 12.10%
# 12.14%
# 11.42%
# 12.22%
# 12.25%
# 11.87%
# 11.68%
# 12.37%
# 11.87%
# 12.44%
# 12.22%
# 12.52%
# 11.42%
# 12.59%
# 12.63%
# 12.67%
# 12.71%
# 12.75%
# 12.78%
# 12.37%
# 12.86%
# 12.90%
# 12.94%
# 12.97%
# 11.38%
# 13.05%
# 11.46%
# 12.59%
# 13.16%
# 13.20%
# 13.24%
# 13.28%
# 12.06%
# 13.35%
# 13.39%
# 11.53%
# 13.47%
# 13.51%
# 13.54%
# 13.58%
# 13.62%
# 13.66%
# 13.69%
# 11.72%
# 11.68%
# 13.81%
# 13.85%
# 11.80%
# 13.92%
# 13.96%
# 12.22%
# 14.04%
# 11.76%
# 14.11%
# 14.15%
# 14.19%
# 13.58%
# 14.26%
# 14.30%
# 11.42%
# 14.38%
# 14.42%
# 11.87%
# 12.06%
# 14.53%
# 11.42%
# 14.61%
# 14.61%
# 12.22%
# 14.15%
# 12.22%
# 11.57%
# 13.24%
# 11.46%
# 12.10%
# 13.69%
# 14.98%
# 15.02%
# 12.22%
# 11.76%
# 13.96%
# 13.51%
# 13.24%
# 15.25%
# 15.29%
# 12.22%
# 13.24%
# 12.22%
# 12.06%
# 13.51%
# 14.19%
# 12.22%
# 13.39%
# 12.06%
# 13.92%
# 11.53%
# 11.76%
# 14.53%
# 12.06%
# 11.53%
# 12.59%
# 14.15%
# 11.87%
# 13.35%
# 14.61%
# 16.08%
# 12.10%
# 12.37%
# 16.20%
# 16.24%
# 11.87%
# 12.59%
# 11.87%
# 11.87%
# 12.37%
# 13.51%
# 11.46%
# 12.06%
# 11.95%
# 16.62%
# 16.65%
# 16.69%
# 11.57%
# 13.96%
# 12.06%
# 12.63%
# 14.61%
# 12.59%
# 16.96%
# 11.68%
# 13.69%
# 14.15%
# 13.96%
# 13.96%
# 17.19%
# 11.95%
# 17.26%
# 17.30%
# 11.53%
# 12.59%
# 12.59%
# 12.37%
# 11.72%
# 11.46%
# 11.87%
# 12.10%
# 17.64%
# 12.10%
# 13.92%
# 11.57%
# 11.91%
# 17.83%
# 13.35%
# 12.22%
# 13.24%
# 11.68%
# 12.63%
# 13.92%
# 13.81%
# 11.42%
# 12.59%
# 12.63%
# 11.87%
# 12.63%
# 4413.20%
# 11.42%
# 4413.28%
# 4413.32%
# 4413.35%
# 12.22%
# 4413.43%
# 4413.47%
# 4413.51%
# 4413.54%
# 4413.58%
# 4413.62%
# 4413.66%
# 4413.69%
# 4413.73%
# 4413.77%
# 4413.81%
# 4413.85%
# 4413.88%
# 4413.92%
# 4413.96%
# 4414.00%
# 4414.04%
# 4414.07%
# 4414.11%
# 4414.15%
# 4414.19%
# 17.64%
# 4414.26%
# 4414.30%
# 4414.34%
# 4414.38%
# 4414.42%
# 4414.45%
# 4414.49%
# 4414.53%
# 4414.57%
# 4414.61%
# 4414.64%
# 4414.68%
# 4414.72%
# 4414.76%
# 4414.80%
# 4414.83%
# 4414.87%
# 4414.91%

# %%
vecs.to_pickle("czech")

# %%
#vecs.to_csv("dutch_danish.csv")

# %%
translator = Translator()
LANGUAGES[translator.detect('moramo znati kakve proizvode kupujemo').lang]
# Out:
# 'croatian'

# %%
data_de_ouf = pd.read_csv("dutch_danish.csv")

# %%
data_de_ouf.columns
# Out:
# Index(['Unnamed: 0', 'content'], dtype='object')

# %%
data_de_ouf.set_index("Unnamed: 0",inplace=True)

# %%
data_de_ouf[""]
# Out:
#                                                       content
# Unnamed: 0
# 5676        [array([-6.17971e-02, -7.04935e-02, -2.45169e-...
# 5677        [array([ 2.50098e-02, -5.89277e-03,  6.28855e-...
# 5678        [array([-0.0324474 , -0.0462027 , -0.00872643,...
# 5679        [array([-4.48872e-02,  2.14520e-02, -3.36201e-...
# 5680        [array([ 4.40220e-02, -1.75716e-02,  1.35894e-...
# ...                                                       ...
# 53735       [array([-1.06169e-01, -2.88038e-02, -3.92888e-...
# 53736       [array([-8.47695e-03,  2.10797e-02, -3.06245e-...
# 53737       [array([-2.46050e-02, -4.23989e-03, -6.23185e-...
# 53738       [array([ 1.85329e-02, -1.02918e-01, -1.19836e-...
# 53739       [array([ 2.45397e-03, -1.91685e-02,  2.06434e-...
#
# [2270 rows x 1 columns]

# %%
df_attempt = pd.read_pickle("dutch_danish")

# %%
pickle_df = pd.DataFrame(df_attempt)
pickle_df = pickle_df.reset_index()

# %%
pickle_df
# Out:
#         index                                            content
# 0        5676  [[-0.0617971, -0.0704935, -0.0245169, 0.067761...
# 1        5677  [[0.0250098, -0.00589277, 0.0628855, 0.0705047...
# 2        5678  [[-0.0324474, -0.0462027, -0.00872643, 0.09936...
# 3        5679  [[-0.0448872, 0.021452, -0.0336201, 0.112377, ...
# 4        5680  [[0.044022, -0.0175716, 0.0135894, -0.00417867...
# ...       ...                                                ...
# 11225  132290  [[-0.0347214, -0.0174933, -0.0307816, 0.038113...
# 11226  132291  [[-0.126007, -0.0443534, -0.009703, 0.0663761,...
# 11227  132292  [[-0.0224834, -0.0404983, -0.0590012, 0.023879...
# 11228  132293  [[0.0510281, 0.00867496, -0.00653633, -0.00882...
# 11229  132294  [[-0.0496591, -0.0732693, 0.0299527, 0.0747977...
#
# [11230 rows x 2 columns]

# %%
pickle_df[pickle_df["content"]=="None"]
# Out:
# Empty DataFrame
# Columns: [content]
# Index: []

# %%
old_data = pd.read_pickle("../../delphes/data/extended_tweet_df")
old_data = old_data.reset_index()

# %%
merger = old_data.merge(pickle_df,on="index")

# %%
merger.to_pickle("merger")

# %%
merger
# Out:
#         index mep_id            name      country  \
# 0        5076  28161  Margrete AUKEN      Denmark
# 1        5077  28161  Margrete AUKEN      Denmark
# 2        5078  28161  Margrete AUKEN      Denmark
# 3        5079  28161  Margrete AUKEN      Denmark
# 4        5080  28161  Margrete AUKEN      Denmark
# ...       ...    ...             ...          ...
# 11225  133995   5392    Lara WOLTERS  Netherlands
# 11226  133996   5392    Lara WOLTERS  Netherlands
# 11227  133997   5392    Lara WOLTERS  Netherlands
# 11228  133998   5392    Lara WOLTERS  Netherlands
# 11229  133999   5392    Lara WOLTERS  Netherlands
#
#                                                    group  \
# 0             Group of the Greens/European Free Alliance
# 1             Group of the Greens/European Free Alliance
# 2             Group of the Greens/European Free Alliance
# 3             Group of the Greens/European Free Alliance
# 4             Group of the Greens/European Free Alliance
# ...                                                  ...
# 11225  Group of the Progressive Alliance of Socialist...
# 11226  Group of the Progressive Alliance of Socialist...
# 11227  Group of the Progressive Alliance of Socialist...
# 11228  Group of the Progressive Alliance of Socialist...
# 11229  Group of the Progressive Alliance of Socialist...
#
#                      nat_group        twitter  \
# 0      Socialistisk Folkeparti  MargreteAuken
# 1      Socialistisk Folkeparti  MargreteAuken
# 2      Socialistisk Folkeparti  MargreteAuken
# 3      Socialistisk Folkeparti  MargreteAuken
# 4      Socialistisk Folkeparti  MargreteAuken
# ...                        ...            ...
# 11225     Partij van de Arbeid  larawoltersEU
# 11226     Partij van de Arbeid  larawoltersEU
# 11227     Partij van de Arbeid  larawoltersEU
# 11228     Partij van de Arbeid  larawoltersEU
# 11229     Partij van de Arbeid  larawoltersEU
#
#                                                content_x  \
# 0      Hvornår agerer #Bagmandspolitiet på anmeldelse...
# 1               “Særligt” ansvar https://t.co/DoXm59xFsc
# 2      Here is the text of our appeal to STOP NORD ST...
# 3      Amazonas brænder, og skov- og klimakrisen er a...
# 4      Covid-19 vaccine makers lobby the EU for immun...
# ...                                                  ...
# 11225  A more socially and environmentally sustainabl...
# 11226                            https://t.co/CwKFTJMz8Y
# 11227  Goed gesprek met @EUombudsman Emily O’Reilly o...
# 11228    @pieterzwaan Ja hoor! Graag naar mijn EP email.
# 11229  https://t.co/CPvJzq9lQZ\nMooi! D66 maakt einde...
#
#                                                content_y
# 0      [False, [0.101227, -0.00355242, -0.0613298, 0....
# 1                                                   None
# 2      [[-0.0540806, 0.0168135, 0.0596281, 0.0681775,...
# 3      [[0.00612917, 0.0156791, -0.0486738, 0.0480299...
# 4      [False, [-0.0484475, 0.011017, -0.0737066, 0.0...
# ...                                                  ...
# 11225  [[0.0495577, 0.129444, -0.0491547, 0.00429166,...
# 11226                                            [False]
# 11227  [[-0.0972181, -0.0736294, 0.00087396, 0.063221...
# 11228  [[-0.0196253, -0.00134424, -0.035015, -0.01173...
# 11229  [[-0.0603085, -0.00909752, -0.0233168, 0.00935...
#
# [11230 rows x 9 columns]
